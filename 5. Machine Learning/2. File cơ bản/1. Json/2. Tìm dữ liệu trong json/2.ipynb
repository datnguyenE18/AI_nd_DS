# %%
import json as js

# %% [markdown]
# Đọc file **json**:

# %%
with open('ColorPoints.json') as json_file:
    data = js.load(json_file)

# %%
data
# Out:
# {'name': 'Color points',
#  'data': [{'coordinate': [0.5639466696914507, 0.4479971628155234],
#    'color': 'yellow',
#    'visible': True},
#   {'coordinate': [0.5859338738690111, 0.6372922215768123],
#    'color': 'yellow',
#    'visible': False},
#   {'coordinate': [0.9922593752966107, 0.6856296591089958],
#    'color': 'red',
#    'visible': False},
#   {'coordinate': [0.5012388549720405, 0.8313948454289805],
#    'color': 'green',
#    'visible': False},
#   {'coordinate': [0.31154917616721456, 0.45200191126353206],
#    'color': 'gray',
#    'visible': True},
#   {'coordinate': [0.2512341896495175, 0.24692474774150364],
#    'color': 'yellow',
#    'visible': False},
#   {'coordinate': [0.3576277428094603, 0.6626158050524183],
#    'color': 'red',
#    'visible': False},
#   {'coordinate': [0.41185052415147894, 0.47387640364940553],
#    'color': 'red',
#    'visible': False},
#   {'coordinate': [0.42720652898696465, 0.46633775564037083],
#    'color': 'red',
# ...

# %%
for pt in data['data']:
        if pt["visible"]==True and pt["color"]=="red":
            print(pt["coordinate"])
# Out:
# [0.42720652898696465, 0.46633775564037083]
# [0.9093956376705772, 0.7133802935821397]
# [0.26896015219895586, 0.7646032154652179]
# [0.3567104235788807, 0.8404907674096675]
# [0.8652468763058409, 0.9344556836607866]
# [0.3201998655524372, 0.5690946159951631]
