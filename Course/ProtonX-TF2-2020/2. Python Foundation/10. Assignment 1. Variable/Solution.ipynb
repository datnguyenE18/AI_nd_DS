# %%
# Complete!

# %% [markdown]
# ## Bài tập biến

# %% [markdown]
# 1. Định nghĩa biến x có giá trị 10

# %%
# Lập trình tại đây
x = 10

# %% [markdown]
# 2. Định nghĩa biến `y` có giá trị "ProtonX"

# %%
# Lập trình tại đây
y = "ProtonX"

# %% [markdown]
# 3. Định nghĩa 2 biến `a` và `b` có giá trị lần lượt -1 và 10

# %%
# Lập trình tại đây
a = -1
b = 10

# %% [markdown]
# 4. Cộng 2 biến `a` và `b` và lưu vào biến `c`

# %%
# Lập trình tại đây
c = a + b

# %% [markdown]
# 5. Bình phương biến `c` và lưu lại chính biến `c` này

# %%
# Lập trình tại đây
c = c ** 2

# %% [markdown]
# 6. Đây là cách giá trị đồng thời cho nhiều biến
# `x, y, z = "Orange", "Banana", "Cherry"`
# Hãy in ba biến này

# %%
# Lập trình tại đây
x, y, z = "Orange", "Banana", "Cherry"
print(x, y, z)
# Out:
# Orange Banana Cherry

# %% [markdown]
# 7. Tạo biến `address` với giá trị là nơi bạn đang sinh sống

# %%
# Lập trình tại đây
address = 'Thanh Trì'

# %% [markdown]
# 8. In ra "Tôi đang sống ở ...". ... được thay bằng giá trị address bạn vừa gán phía bên trên

# %%
# Lập trình tại đây
print('Tôi đang sống ở {}'.format(address))
# Out:
# Tôi đang sống ở Thanh Trì

# %% [markdown]
# 9. Một học viên có thông tin như sau
# - Tên: Nguyễn văn X
# - Tuổi: 22
# - Đơn vị công tác: X Company
# - Vị trí: Software Engineer
#
# Lập 4 biến `name, age, company, position` để lưu thông tin của học viên này

# %%
# Lập trình tại đây
name = 'Nguyễn văn X'
age = 22
company = 'X Company'
position = 'Software Engineer'

# %% [markdown]
# 10. Lập trình chat bot theo yêu cầu dưới đây
# ![2.PNG](data:image/png;base64,...)

# %%
print('Tôi là vua của phép cộng')
a = int(input('Vui lòng nhập a: '))
b = int(input('Vui lòng nhập b: '))
print('a + b = {}'.format(a + b))
# Out:
# Tôi là vua của phép cộng
# Vui lòng nhập a: 4
# Vui lòng nhập b: 5
# a + b = 9
