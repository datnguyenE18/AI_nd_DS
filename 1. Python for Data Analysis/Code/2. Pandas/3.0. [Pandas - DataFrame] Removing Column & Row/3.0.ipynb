# %%
import pandas as pd
import random
df = pd.read_csv('pp.csv') 
df
# Out:
#     person_ID                        name               email  \
# 0        3130             Burks, Rosella      BurksR@univ.edu
# 1        3297              Avila, Damien      AvilaD@univ.edu
# 2        3547               Olsen, Robin      OlsenR@univ.edu
# 3        1538         Moises, Edgar Estes    MoisesE@univ.edu
# 4        2941         Brian, Heath Pruitt     BrianH@univ.edu
# 5        2401         Claude, Elvin Haney    ClaudeE@univ.edu
# 6        2070             Mosley, Edmund     MosleyE@univ.edu
# 7        2561        Derek, Antoine Mccoy     DerekA@univ.edu
# 8        1625            Hawkins, Callie    HawkinsC@univ.edu
# 9        1307               Pate, Andrea       PateA@univ.edu
# 10       2342                Austin, Liz     AustinL@univ.edu
# 11       2755       Kendrick, Reba Alford  KendrickR@univ.edu
# 12       4150             Sims, Angelina       SimsA@univ.edu
# 13       3544          Mullins, Kimberly    MullinsK@univ.edu
# ...

# %% [markdown]
# ### Editing column:

# %%
df['name'][9] = 'Đạt' 
df['email'][9] = 'Datnguyen@gmail.com' 
df['fax'] = df['phone'] = ''
df
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Dell\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     person_ID                        name                email phone fax  \
# 0        3130             Burks, Rosella       BurksR@univ.edu
# 1        3297              Avila, Damien       AvilaD@univ.edu
# 2        3547               Olsen, Robin       OlsenR@univ.edu
# 3        1538         Moises, Edgar Estes     MoisesE@univ.edu
# ...

# %% [markdown]
# ### Removing column:

# %%
# tạm ẩn cột 'phone':
df.drop('phone', axis = 1)
# Out:
#     person_ID                        name                email fax  \
# 0        3130             Burks, Rosella       BurksR@univ.edu
# 1        3297              Avila, Damien       AvilaD@univ.edu
# 2        3547               Olsen, Robin       OlsenR@univ.edu
# 3        1538         Moises, Edgar Estes     MoisesE@univ.edu
# 4        2941         Brian, Heath Pruitt      BrianH@univ.edu
# 5        2401         Claude, Elvin Haney     ClaudeE@univ.edu
# 6        2070             Mosley, Edmund      MosleyE@univ.edu
# 7        2561        Derek, Antoine Mccoy      DerekA@univ.edu
# 8        1625            Hawkins, Callie     HawkinsC@univ.edu
# 9        1307                         Đạt  Datnguyen@gmail.com
# 10       2342                Austin, Liz      AustinL@univ.edu
# 11       2755       Kendrick, Reba Alford   KendrickR@univ.edu
# 12       4150             Sims, Angelina        SimsA@univ.edu
# 13       3544          Mullins, Kimberly     MullinsK@univ.edu
# ...

# %%
# Xóa hẳn cột phone:
df.drop('phone', axis = 1, inplace = True)
df
# Out:
#     person_ID                        name                email fax  \
# 0        3130             Burks, Rosella       BurksR@univ.edu
# 1        3297              Avila, Damien       AvilaD@univ.edu
# 2        3547               Olsen, Robin       OlsenR@univ.edu
# 3        1538         Moises, Edgar Estes     MoisesE@univ.edu
# 4        2941         Brian, Heath Pruitt      BrianH@univ.edu
# 5        2401         Claude, Elvin Haney     ClaudeE@univ.edu
# 6        2070             Mosley, Edmund      MosleyE@univ.edu
# 7        2561        Derek, Antoine Mccoy      DerekA@univ.edu
# 8        1625            Hawkins, Callie     HawkinsC@univ.edu
# 9        1307                         Đạt  Datnguyen@gmail.com
# 10       2342                Austin, Liz      AustinL@univ.edu
# 11       2755       Kendrick, Reba Alford   KendrickR@univ.edu
# 12       4150             Sims, Angelina        SimsA@univ.edu
# 13       3544          Mullins, Kimberly     MullinsK@univ.edu
# ...

# %%
# Xóa cột ID và cột Fax:
df.drop(['person_ID', 'fax'], axis = 1, inplace = True)
df
# Out:
#                           name                email                title  age  \
# 0              Burks, Rosella       BurksR@univ.edu            Professor   25
# 1               Avila, Damien       AvilaD@univ.edu           Professor    23
# 2                Olsen, Robin       OlsenR@univ.edu  Assistant Professor   21
# 3          Moises, Edgar Estes     MoisesE@univ.edu            Professor   18
# 4          Brian, Heath Pruitt      BrianH@univ.edu   Associate Curator    30
# 5          Claude, Elvin Haney     ClaudeE@univ.edu              Curator   35
# 6              Mosley, Edmund      MosleyE@univ.edu  Assistant Professor   35
# 7         Derek, Antoine Mccoy      DerekA@univ.edu              Curator   35
# 8             Hawkins, Callie     HawkinsC@univ.edu            Professor   29
# 9                          Đạt  Datnguyen@gmail.com            Professor   29
# 10                Austin, Liz      AustinL@univ.edu  Assistant Professor   28
# ...

# %%
# Xóa bản ghi ở chỉ số 0 và 1:
df.drop([0,1], inplace = True) # = df.drop([0,1], axis = 0, inplace = True)
df
# Out:
#                           name                email                title  age  \
# 2                Olsen, Robin       OlsenR@univ.edu  Assistant Professor   21
# 3          Moises, Edgar Estes     MoisesE@univ.edu            Professor   18
# 4          Brian, Heath Pruitt      BrianH@univ.edu   Associate Curator    30
# 5          Claude, Elvin Haney     ClaudeE@univ.edu              Curator   35
# 6              Mosley, Edmund      MosleyE@univ.edu  Assistant Professor   35
# 7         Derek, Antoine Mccoy      DerekA@univ.edu              Curator   35
# 8             Hawkins, Callie     HawkinsC@univ.edu            Professor   29
# 9                          Đạt  Datnguyen@gmail.com            Professor   29
# 10                Austin, Liz      AustinL@univ.edu  Assistant Professor   28
# 11       Kendrick, Reba Alford   KendrickR@univ.edu   Associate Curator    23
# 12             Sims, Angelina        SimsA@univ.edu            Professor   22
# ...
