# %%
import cv2
mat = cv2.imread("img.png", cv2.IMREAD_GRAYSCALE)
mat
# Out:
# array([[ 33,  31,  33, ..., 124, 129, 132],
#        [ 33,  29,  29, ..., 125, 125, 128],
#        [ 36,  32,  32, ..., 123, 123, 126],
#        ...,
#        [ 52,  54,  59, ...,  58,  69,  89],
#        [ 56,  58,  60, ...,  71,  74,  85],
#        [ 61,  58,  59, ...,  80,  73,  74]], dtype=uint8)

# %%
cv2.imshow("img", mat)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# ![1.png](attachment:1.png)
