# %% [markdown]
# *In the real world, a Pandas DataFrame will be created by loading the datasets from existing storage, storage can be SQL Database, CSV file, and Excel file. Pandas DataFrame can be created from the lists, dictionary, and from a list of dictionary etc. Dataframe can be created in different ways*

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **General way:**

# %%
# Import randn from random (Numpy)
from numpy.random import randn

df = pd.DataFrame(100 + 10, index = 'A B C D E'.split(), columns = 'W X Y Z'.split())
#or: df = pd.DataFrame(100, index = ['A', 'B', 'C', 'D', 'E'], columns = ['W', 'X', 'Y', 'Z'])

# Show: 
df
# Out:
#      W    X    Y    Z
# A  110  110  110  110
# B  110  110  110  110
# C  110  110  110  110
# D  110  110  110  110
# E  110  110  110  110

# %%
pd.DataFrame(randn(5, 4), index = [2, 8, 9, 10, 20], columns = 'W X Y Z'.split())
# Out:
#            W         X         Y         Z
# 2  -0.552927  1.548071 -1.587529  1.705745
# 8   1.104995 -0.397064  0.199934  0.521587
# 9   0.152551  1.006296 -0.419951 -0.229828
# 10  1.008116  1.459609 -0.532693  0.065963
# 20  1.317912 -0.937381  0.494796 -1.544633

# %%
pd.DataFrame(randn(5, 6), index = [1, 2, 3, 4, 5], columns =[1, 2, 3, 4, 5, 6])
# Out:
#           1         2         3         4         5         6
# 1 -2.046023  0.702477 -1.077879  0.141530 -1.371229  1.272690
# 2 -1.974747  0.759947  0.413511 -2.265239  0.427483  0.135752
# 3 -0.004721 -2.612372 -0.363075 -0.816882  0.307137 -1.261452
# 4  1.347228 -0.680657  0.190919  0.181504 -0.497494  1.458367
# 5  0.950738  0.828125 -0.961606 -1.017187 -0.811697  1.329358

# %%
np.random.seed(101)
pd.DataFrame(randn(3, 2), index = [1, 2, 3], columns =[1, 2])
# Out:
#           1         2
# 1  2.706850  0.628133
# 2  0.907969  0.503826
# 3  0.651118 -0.319318

# %%
np.random.seed(101)
print (randn(3, 2))
# Out:
# [[ 2.70684984  0.62813271]
#  [ 0.90796945  0.50382575]
#  [ 0.65111795 -0.31931804]]

# %%
people = {'name' : ['Nguyen Van A', 'Nguyen Thi B'], 'age' : [28, 29], 'website' : ['NguyenVanA.com', 'NguyenThiB.vn']}
pd.DataFrame(people)
# Out:
#            name  age         website
# 0  Nguyen Van A   28  NguyenVanA.com
# 1  Nguyen Thi B   29   NguyenThiB.vn

# %% [markdown]
# **Using List:**

# %%
lst = [['VietNam', 'America', 'England', 'France', 'China'], ['Korea', 'Japan', 'Italy', 'Germany', 'Iceland']]

# %%
lst
# Out:
# [['VietNam', 'America', 'England', 'France', 'China'],
#  ['Korea', 'Japan', 'Italy', 'Germany', 'Iceland']]

# %%
df = pd.DataFrame( data = lst, columns = 'A B C D E'.split())
df
# Out:
#          A        B        C        D        E
# 0  VietNam  America  England   France    China
# 1    Korea    Japan    Italy  Germany  Iceland

# %%
txts = ['Good', 'Medium', 'Bad']
score = [10, 8, 5]
df = pd.DataFrame()
df['txt'] = txts
df['score'] = score
df
# Out:
#       txt  score
# 0    Good     10
# 1  Medium      8
# 2     Bad      5

# %% [markdown]
# **From dict of ndarray/lists:**

# %%
data = {
    'Name' : 'Tuan Anh Dam Duc An'.split(), 
    'Age' : [20, 21, 23, 25, 26],
    'Score' : [100, 99, 95, 93, 97]
}

# %%
df = pd.DataFrame(data, index = '1st 2nd 3rd 4th 5th'.split())
df
# Out:
#      Name  Age  Score
# 1st  Tuan   20    100
# 2nd   Anh   21     99
# 3rd   Dam   23     95
# 4th   Duc   25     93
# 5th    An   26     97

# %% [markdown]
# **From a file:**

# %% [markdown]
# * If "data_folder.csv" is in the same directory as the "Python.py" file:

# %%
df = pd.read_csv('nba.csv') 
# show:
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  06-Oct     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# * "data_folder.csv" is in other directory:

# %%
af = pd.read_csv('D:/GitHub/Data_Science/Python for Data Analysis/Code/2.7. [Pandas - DataFrame] Creat a Pandas DataFrame/nba.csv')
# or: af = pd.read_csv('../2.7. [Pandas - DataFrame] Creat a Pandas DataFrame/nba.csv')
af
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  06-Oct     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
bf = pd.read_csv('../../Dell/Desktop/nba.csv')
bf
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  06-Oct     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
cf = pd.read_csv('../Desktop/nba.csv')
cf
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  06-Oct     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...
