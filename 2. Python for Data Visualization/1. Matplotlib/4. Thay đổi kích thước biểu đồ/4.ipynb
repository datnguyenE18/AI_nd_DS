# %% [markdown]
# # Thay đổi kích thước của biểu đồ

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 5, 11)
y = x ** 3 + 1

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([  1.   ,   1.125,   2.   ,   4.375,   9.   ,  16.625,  28.   ,
#         43.875,  65.   ,  92.125, 126.   ])

# %% [markdown]
# Ta sử dụng phương thức **figure()** để thay đổi kích thước của biểu đồ, tham số truyền vào là **figsize**.

# %%
plt.figure(figsize = (10, 7)) # 10 chiều rộng và 7 chiều cao
plt.plot(x, y)
plt.xlim(0, 5) # độ chia
plt.ylim(0, 150) # độ chia
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Basic Example')
# Out:
# Text(0.5, 1.0, 'Basic Example')

# %% [markdown]
# Ở ví dụ trên tham số truyền vào là **figsize = (10,7)** trong đó 10 là tỉ lệ độ dài trục ngang (x) và 7 là tỉ lệ độ dài trục dọc (y)
#
# Ta cũng thấy có **plt.xlim** và **plt.ylim**. Hai phương thức này dùng để xác định hệ số chia trên trục tương ứng.
